# %%
# %pip install -qU langgraph langchain langchain-google-genai langchain-tavily python-dotenv aiosqlite langgraph-checkpoint-sqlite
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GEMINI_API_KEY = os.getenv('GEMINI_API_KEY') 
TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')

# %%
import operator
from typing import Annotated, List, Any, Dict
from dataclasses import dataclass, field
from langgraph.graph import StateGraph, END
from langchain_core.messages import HumanMessage, SystemMessage, ToolMessage, BaseMessage, AnyMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_tavily import TavilySearch
from langgraph.checkpoint.sqlite import SqliteSaver
from typing_extensions import TypedDict
import sqlite3
# Out:
# d:\Videos - Cursos\TIME_LATAM\Alvaro\Videos_2255\MULTIAGENTES_LANGGRAPH\.venv\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "output_schema" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# d:\Videos - Cursos\TIME_LATAM\Alvaro\Videos_2255\MULTIAGENTES_LANGGRAPH\.venv\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "stream" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

conn = sqlite3.connect("checkpoints.db", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        
        graph = StateGraph(AgentState)

        graph.add_node("llm", self.call_gemini)

        graph.add_node("action", self.take_action)

        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})

        graph.add_edge("action", "llm")

        graph.set_entry_point("llm")

        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_gemini(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages

        print("Mensajes enviados al modelo:", messages)
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Llamando la Herramienta: {t['name']} con los siguientes argumentos: {t['args']}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Retornando a la LLM tras la acción!")
        return {'messages': results}

# %%
# current_tavily_api_key = os.getenv('TAVILY_API_KEY')
if not TAVILY_API_KEY:
    raise ValueError("TAVILY_API_KEY não encontrada. Certifique-se de que está no seu .env e python-dotenv está instalado.")

tool = TavilySearch(max_results=3, tavily_api_key=TAVILY_API_KEY)


prompt_system = """
Eres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.
Tienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).
Busca información únicamente cuando tengas certeza de qué buscar.
Si necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.
Cuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.
"""

model = ChatGoogleGenerativeAI(model="gemini-2.5-pro") 

abot = Agent(model, [tool], system=prompt_system, checkpointer=memory)

# %%
messages = [HumanMessage(content="Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?")]
thread = {"configurable": {"thread_id": "3"}} 


print("\n--- Pregunta 1: Clima en Lima ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"): 
             print(f"{k}: {v['messages']}")
# Out:
# --- Pregunta 1: Clima en Lima ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa en diciembre"}'}, '__gemini_function_call_thought_signatures__': {'302419a5-d036-451b-9844-ff2ab26d1bb0': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-a603-7441-a3c0-693aacd7b6a5-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú en diciembre'}, 'id': '302419a5-d036-451b-9844-ff2ab26d1bb0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1534, 'output_tokens': 492, 'total_tokens': 2026, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 469}}), ToolMessage(content="{'query': 'clima en Lima Perú en diciembre', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://wanderlog.com/es/weather/135226/12/clima-de-lima-en-diciembre', 'title': 'Clima de Lima, Perú en diciembre: temperatura promedio y ...', 'content': 'El clima en Lima en diciembre es ligeramente fresco y ventoso, con máximas promedio de 72°F (22°C) y mínimas de 62°F (17°C).', 'score': 0.95857275, 'raw_content': None}, {'url': 'https://www.tiempo3.com/south-america/peru/lima?page=month&month=December', 'title': 'Clima en Lima en diciembre 2025', 'content': 'Durante el mes de diciembre 2025, Lima experimentará temperaturas mínimas de 11°C y máximas de hasta 20°C. Si bien es verdad que el clima será agradable,', 'score': 0.95334905, 'raw_content': None}, {'url': 'https://es.weatherspark.com/m/20441/12/Tiempo-promedio-en-diciembre-en-Lima-Per%C3%BA', 'title': 'El tiempo en Lima en diciembre, temperatura promedio ...', 'content': 'El tiempo en diciembre en Lima Perú Las temperaturas máximas diarias aumentan 2 °C, de 23 °C a 25 °C y rara vez bajan a menos de 21 °C o exceden 27 °C. Las', 'score': 0.93911994, 'raw_content': None}], 'response_time': 0.96, 'request_id': '52f1ccb6-f538-4ff3-93da-25bf7c073440'}", name='tavily_search', tool_call_id='302419a5-d036-451b-9844-ff2ab26d1bb0'), AIMessage(content=[{'type': 'text', 'text': 'No es posible darte el pronóstico del tiempo exacto para una fecha tan lejana como el 29 de diciembre de 2025.\n\nSin embargo, basándome en los datos históricos y promedios para Lima, Perú, en el mes de diciembre, puedes esperar lo siguiente:\n\n*   **Temperaturas:** Las temperaturas máximas diarias suelen aumentar a lo largo del mes, generalmente oscilando entre los **22°C y 25°C**. Las temperaturas mínimas por la noche rondan los **17°C**.\n*   **Sensación general:** El clima es generalmente agradable y algo ventoso.\n\nTe recomiendo que consultes un pronóstico del tiempo más cerca de la fecha para obtener información precisa.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-c3a8-7540-b8c6-bfe8b3afc8a2-0', usage_metadata={'input_tokens': 2075, 'output_tokens': 610, 'total_tokens': 2685, 'input_token_details': {'cache_read': 0}, 'output_to ...
# llm: [AIMessage(content=[{'type': 'text', 'text': 'No puedo darte el pronóstico del tiempo exacto para una fecha futura como el 29 de diciembre de 2025. Los pronósticos meteorológicos detallados solo están disponibles con unos días de antelación.\n\nSin embargo, basándome en los datos históricos del clima para Lima en diciembre, puedes esperar lo siguiente:\n\n*   **Temperaturas máximas:** Generalmente aumentan a lo largo del mes, oscilando entre **23°C y 25°C**.\n*   **Temperaturas mínimas:** Suelen rondar los **17°C**.\n*   **Condiciones generales:** El clima suele ser agradable y un poco ventoso.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6858-c717-7cf0-a5f4-3ed37b2c9924-0', usage_metadata={'input_tokens': 2254, 'output_tokens': 495, 'total_tokens': 2749, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 351}})]

# %%
messages = [HumanMessage(content="Y el clima en Medellín?")]
thread = {"configurable": {"thread_id": "3"}} 

print("\n--- Pregunta 2: Clima en Medellín ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pregunta 2: Clima en Medellín ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa en diciembre"}'}, '__gemini_function_call_thought_signatures__': {'302419a5-d036-451b-9844-ff2ab26d1bb0': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-a603-7441-a3c0-693aacd7b6a5-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú en diciembre'}, 'id': '302419a5-d036-451b-9844-ff2ab26d1bb0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1534, 'output_tokens': 492, 'total_tokens': 2026, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 469}}), ToolMessage(content="{'query': 'clima en Lima Perú en diciembre', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://wanderlog.com/es/weather/135226/12/clima-de-lima-en-diciembre', 'title': 'Clima de Lima, Perú en diciembre: temperatura promedio y ...', 'content': 'El clima en Lima en diciembre es ligeramente fresco y ventoso, con máximas promedio de 72°F (22°C) y mínimas de 62°F (17°C).', 'score': 0.95857275, 'raw_content': None}, {'url': 'https://www.tiempo3.com/south-america/peru/lima?page=month&month=December', 'title': 'Clima en Lima en diciembre 2025', 'content': 'Durante el mes de diciembre 2025, Lima experimentará temperaturas mínimas de 11°C y máximas de hasta 20°C. Si bien es verdad que el clima será agradable,', 'score': 0.95334905, 'raw_content': None}, {'url': 'https://es.weatherspark.com/m/20441/12/Tiempo-promedio-en-diciembre-en-Lima-Per%C3%BA', 'title': 'El tiempo en Lima en diciembre, temperatura promedio ...', 'content': 'El tiempo en diciembre en Lima Perú Las temperaturas máximas diarias aumentan 2 °C, de 23 °C a 25 °C y rara vez bajan a menos de 21 °C o exceden 27 °C. Las', 'score': 0.93911994, 'raw_content': None}], 'response_time': 0.96, 'request_id': '52f1ccb6-f538-4ff3-93da-25bf7c073440'}", name='tavily_search', tool_call_id='302419a5-d036-451b-9844-ff2ab26d1bb0'), AIMessage(content=[{'type': 'text', 'text': 'No es posible darte el pronóstico del tiempo exacto para una fecha tan lejana como el 29 de diciembre de 2025.\n\nSin embargo, basándome en los datos históricos y promedios para Lima, Perú, en el mes de diciembre, puedes esperar lo siguiente:\n\n*   **Temperaturas:** Las temperaturas máximas diarias suelen aumentar a lo largo del mes, generalmente oscilando entre los **22°C y 25°C**. Las temperaturas mínimas por la noche rondan los **17°C**.\n*   **Sensación general:** El clima es generalmente agradable y algo ventoso.\n\nTe recomiendo que consultes un pronóstico del tiempo más cerca de la fecha para obtener información precisa.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-c3a8-7540-b8c6-bfe8b3afc8a2-0', usage_metadata={'input_tokens': 2075, 'output_tokens': 610, 'total_tokens': 2685, 'input_token_details': {'cache_read': 0}, 'output_to ...
# llm: [AIMessage(content=[{'type': 'text', 'text': '¿Para qué fecha te gustaría saber el clima en Medellín? ¿Te refieres a la misma fecha, 29 de diciembre de 2025, o a la fecha actual?', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6859-4a1f-7291-b602-f51ea963ec11-0', usage_metadata={'input_tokens': 2406, 'output_tokens': 414, 'total_tokens': 2820, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 375}})]

# %%
messages = [HumanMessage(content="Cuál ciudad está más caliente?")]
thread = {"configurable": {"thread_id": "3"}} 

print("\n--- Pregunta 3: Comparación ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pregunta 3: Comparación ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa en diciembre"}'}, '__gemini_function_call_thought_signatures__': {'302419a5-d036-451b-9844-ff2ab26d1bb0': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-a603-7441-a3c0-693aacd7b6a5-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú en diciembre'}, 'id': '302419a5-d036-451b-9844-ff2ab26d1bb0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1534, 'output_tokens': 492, 'total_tokens': 2026, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 469}}), ToolMessage(content="{'query': 'clima en Lima Perú en diciembre', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://wanderlog.com/es/weather/135226/12/clima-de-lima-en-diciembre', 'title': 'Clima de Lima, Perú en diciembre: temperatura promedio y ...', 'content': 'El clima en Lima en diciembre es ligeramente fresco y ventoso, con máximas promedio de 72°F (22°C) y mínimas de 62°F (17°C).', 'score': 0.95857275, 'raw_content': None}, {'url': 'https://www.tiempo3.com/south-america/peru/lima?page=month&month=December', 'title': 'Clima en Lima en diciembre 2025', 'content': 'Durante el mes de diciembre 2025, Lima experimentará temperaturas mínimas de 11°C y máximas de hasta 20°C. Si bien es verdad que el clima será agradable,', 'score': 0.95334905, 'raw_content': None}, {'url': 'https://es.weatherspark.com/m/20441/12/Tiempo-promedio-en-diciembre-en-Lima-Per%C3%BA', 'title': 'El tiempo en Lima en diciembre, temperatura promedio ...', 'content': 'El tiempo en diciembre en Lima Perú Las temperaturas máximas diarias aumentan 2 °C, de 23 °C a 25 °C y rara vez bajan a menos de 21 °C o exceden 27 °C. Las', 'score': 0.93911994, 'raw_content': None}], 'response_time': 0.96, 'request_id': '52f1ccb6-f538-4ff3-93da-25bf7c073440'}", name='tavily_search', tool_call_id='302419a5-d036-451b-9844-ff2ab26d1bb0'), AIMessage(content=[{'type': 'text', 'text': 'No es posible darte el pronóstico del tiempo exacto para una fecha tan lejana como el 29 de diciembre de 2025.\n\nSin embargo, basándome en los datos históricos y promedios para Lima, Perú, en el mes de diciembre, puedes esperar lo siguiente:\n\n*   **Temperaturas:** Las temperaturas máximas diarias suelen aumentar a lo largo del mes, generalmente oscilando entre los **22°C y 25°C**. Las temperaturas mínimas por la noche rondan los **17°C**.\n*   **Sensación general:** El clima es generalmente agradable y algo ventoso.\n\nTe recomiendo que consultes un pronóstico del tiempo más cerca de la fecha para obtener información precisa.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-c3a8-7540-b8c6-bfe8b3afc8a2-0', usage_metadata={'input_tokens': 2075, 'output_tokens': 610, 'total_tokens': 2685, 'input_token_details': {'cache_read': 0}, 'output_to ...
# llm: [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Medell\\u00edn en diciembre"}'}, '__gemini_function_call_thought_signatures__': {'e43ef5e0-ae53-41f9-b7d4-a95c58506490': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6859-ee90-7e72-972c-f1be29830977-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Medellín en diciembre'}, 'id': 'e43ef5e0-ae53-41f9-b7d4-a95c58506490', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2453, 'output_tokens': 631, 'total_tokens': 3084, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 609}})]
# Llamando la Herramienta: tavily_search con los siguientes argumentos: {'query': 'clima en Medellín en diciembre'}
# Retornando a la LLM tras la acción!
# action: [ToolMessage(content="{'query': 'clima en Medellín en diciembre', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.tiempo3.com/south-america/colombia/sucre/medellin?page=month&month=December', 'title': 'Clima en Medellin en diciembre 2025 | Tiempo3.com', 'content': '# Pronóstico meteorológico del clima en Medellin para diciembre de 2025. ## Clima promedio en Medellin en diciembre de 2025. Habrá muchos días de lluvia durante el mes de diciembre en Medellin. | Febrero | **22°** / 12° | 18 | 10 | 0 | 369 mm | Agradable | Medellin en febrero |. | Marzo | **22°** / 13° | 25 | 6 | 0 | 609 mm | Agradable | Medellin en marzo |. | Noviembre | **21°** / 12° | 25 | 5 | 0 | 615 mm | Agradable | Medellin en noviembre |. | Diciembre | **22°** / 11° | 19 | 12 | 0 | 354 mm | Agradable | Medellin en diciembre |. ¿Cuál es la temperatura promedio en Medellin en diciembre? Las temperaturas promedio en Medellin para el mes de diciembre son de **22°** / 11°C. En promedio, en Medellin, hay 19 días de lluvia durante el mes de diciembre. El clima de Medellin en diciembre es agradable.', 'score': 0.99997365, 'raw_content': None}, {'url': 'https://wanderlog.com/es/weather/131079/12/clima-de-medell%C3%ADn-en-diciembre', 'title': 'Clima de Medellín, Colombia en diciembre: temperatura promedio y ...', 'content': '# Clima de Medellín, Colombia en diciembre. Este gráfico muestra cómo es un día promedio en Medellín en diciembre basado en datos históricos. La cantidad promedio de tiempo que el cielo está despejado o soleado (parcialmente nublado o menos) en Medellín durante diciembre es de 4,4 horas (18% del día). Para comparar, el mes con más días despejados y soleados en Medellín es enero con un promedio de 5,5 horas por día, mientras que abril tiene la menor cantidad de horas sin nubes con solo 2,5 horas por día. El día promedio en Medellín durante diciembre tiene 11,8 horas de luz, con el amanecer a las 06:03 y el atardecer a las 17:50. Este gráfico muestra la cantidad promedio de luz diurna en Medellín en diciembre basado en datos históricos. Este gráfico muestra la cantidad promedio de humedad en Medellín a lo largo de diciembre basado en datos históricos. Este gráfico muestra la velocidad promedio del viento en Medellín en diciembre basado en datos históricos.', 'score': 0.9999478, 'raw_content': None}, {'url': 'https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/t/diciembre-12/', 'title': 'Clima en Medellín en diciembre 2025: temperatura y clima', 'content': 'En Medellín, el día más cálido de diciembre es 23.12, con temperaturas que alcanzan 23.7°C. La precipitación diaria en Medellín durante diciembre oscila entre 0.7 mm y 4.3 mm. |  | enero | Febrero | Marzo | Abril | Mayo | junio | julio | agosto | septiembre | octubre | noviembre | diciembre |. El día más cálido de diciembre en Medellín es 23.12, con una temperatura máxima media de 23.7°C. #### ¿Qué parte de diciembre es la más cálida en Medellín según las temperaturas promedio? #### ¿Cuál es la parte más fría de diciembre en Medellín según las temperaturas medias? #### ¿Qué parte de diciembre es la más soleada en Medellín según las horas de sol? #### ¿Qué parte de diciembre es la más oscura en Medellín según las horas de sol? #### ¿Qué día presenta la humedad más baja en Medellín durante diciembre? #### ¿Qué parte de diciembre es la más seca con respecto a la humedad en Medellín?', 'score': 0.9999417, 'raw_content': None}], 'response_time': 1.01, 'request_id': '7c3711c2-a48f-4d1f-90f8-f38b3b1049f1'}", name='tavily_search', tool_call_id='e43ef5e0-ae53-41f9-b7d4-a95c58506490')]
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa en diciembre"}'}, '__gemini_function_call_thought_signatures__': {'302419a5-d036-451b-9844-ff2ab26d1bb0': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-a603-7441-a3c0-693aacd7b6a5-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú en diciembre'}, 'id': '302419a5-d036-451b-9844-ff2ab26d1bb0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1534, 'output_tokens': 492, 'total_tokens': 2026, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 469}}), ToolMessage(content="{'query': 'clima en Lima Perú en diciembre', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://wanderlog.com/es/weather/135226/12/clima-de-lima-en-diciembre', 'title': 'Clima de Lima, Perú en diciembre: temperatura promedio y ...', 'content': 'El clima en Lima en diciembre es ligeramente fresco y ventoso, con máximas promedio de 72°F (22°C) y mínimas de 62°F (17°C).', 'score': 0.95857275, 'raw_content': None}, {'url': 'https://www.tiempo3.com/south-america/peru/lima?page=month&month=December', 'title': 'Clima en Lima en diciembre 2025', 'content': 'Durante el mes de diciembre 2025, Lima experimentará temperaturas mínimas de 11°C y máximas de hasta 20°C. Si bien es verdad que el clima será agradable,', 'score': 0.95334905, 'raw_content': None}, {'url': 'https://es.weatherspark.com/m/20441/12/Tiempo-promedio-en-diciembre-en-Lima-Per%C3%BA', 'title': 'El tiempo en Lima en diciembre, temperatura promedio ...', 'content': 'El tiempo en diciembre en Lima Perú Las temperaturas máximas diarias aumentan 2 °C, de 23 °C a 25 °C y rara vez bajan a menos de 21 °C o exceden 27 °C. Las', 'score': 0.93911994, 'raw_content': None}], 'response_time': 0.96, 'request_id': '52f1ccb6-f538-4ff3-93da-25bf7c073440'}", name='tavily_search', tool_call_id='302419a5-d036-451b-9844-ff2ab26d1bb0'), AIMessage(content=[{'type': 'text', 'text': 'No es posible darte el pronóstico del tiempo exacto para una fecha tan lejana como el 29 de diciembre de 2025.\n\nSin embargo, basándome en los datos históricos y promedios para Lima, Perú, en el mes de diciembre, puedes esperar lo siguiente:\n\n*   **Temperaturas:** Las temperaturas máximas diarias suelen aumentar a lo largo del mes, generalmente oscilando entre los **22°C y 25°C**. Las temperaturas mínimas por la noche rondan los **17°C**.\n*   **Sensación general:** El clima es generalmente agradable y algo ventoso.\n\nTe recomiendo que consultes un pronóstico del tiempo más cerca de la fecha para obtener información precisa.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-c3a8-7540-b8c6-bfe8b3afc8a2-0', usage_metadata={'input_tokens': 2075, 'output_tokens': 610, 'total_tokens': 2685, 'input_token_details': {'cache_read': 0}, 'output_to ...
# llm: [AIMessage(content='Basándonos en el clima promedio para el mes de diciembre, **Lima es generalmente más caliente que Medellín.**\n\n*   **Lima, Perú:** Tiene temperaturas máximas que suelen estar entre **22°C y 25°C**.\n*   **Medellín, Colombia:** Tiene temperaturas máximas promedio alrededor de **22°C y 23.7°C**.\n\nAunque las temperaturas son bastante similares, Lima tiende a tener máximas ligeramente más altas en esa época del año.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b685a-1000-75c3-8f7f-c841c67102dc-0', usage_metadata={'input_tokens': 3588, 'output_tokens': 104, 'total_tokens': 3692, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Cuál ciudad está más caliente?")]
thread = {"configurable": {"thread_id": "3"}} 

print("\n--- Pergunta 4: Comparación ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 4: Comparación ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa en diciembre"}'}, '__gemini_function_call_thought_signatures__': {'302419a5-d036-451b-9844-ff2ab26d1bb0': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-a603-7441-a3c0-693aacd7b6a5-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú en diciembre'}, 'id': '302419a5-d036-451b-9844-ff2ab26d1bb0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1534, 'output_tokens': 492, 'total_tokens': 2026, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 469}}), ToolMessage(content="{'query': 'clima en Lima Perú en diciembre', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://wanderlog.com/es/weather/135226/12/clima-de-lima-en-diciembre', 'title': 'Clima de Lima, Perú en diciembre: temperatura promedio y ...', 'content': 'El clima en Lima en diciembre es ligeramente fresco y ventoso, con máximas promedio de 72°F (22°C) y mínimas de 62°F (17°C).', 'score': 0.95857275, 'raw_content': None}, {'url': 'https://www.tiempo3.com/south-america/peru/lima?page=month&month=December', 'title': 'Clima en Lima en diciembre 2025', 'content': 'Durante el mes de diciembre 2025, Lima experimentará temperaturas mínimas de 11°C y máximas de hasta 20°C. Si bien es verdad que el clima será agradable,', 'score': 0.95334905, 'raw_content': None}, {'url': 'https://es.weatherspark.com/m/20441/12/Tiempo-promedio-en-diciembre-en-Lima-Per%C3%BA', 'title': 'El tiempo en Lima en diciembre, temperatura promedio ...', 'content': 'El tiempo en diciembre en Lima Perú Las temperaturas máximas diarias aumentan 2 °C, de 23 °C a 25 °C y rara vez bajan a menos de 21 °C o exceden 27 °C. Las', 'score': 0.93911994, 'raw_content': None}], 'response_time': 0.96, 'request_id': '52f1ccb6-f538-4ff3-93da-25bf7c073440'}", name='tavily_search', tool_call_id='302419a5-d036-451b-9844-ff2ab26d1bb0'), AIMessage(content=[{'type': 'text', 'text': 'No es posible darte el pronóstico del tiempo exacto para una fecha tan lejana como el 29 de diciembre de 2025.\n\nSin embargo, basándome en los datos históricos y promedios para Lima, Perú, en el mes de diciembre, puedes esperar lo siguiente:\n\n*   **Temperaturas:** Las temperaturas máximas diarias suelen aumentar a lo largo del mes, generalmente oscilando entre los **22°C y 25°C**. Las temperaturas mínimas por la noche rondan los **17°C**.\n*   **Sensación general:** El clima es generalmente agradable y algo ventoso.\n\nTe recomiendo que consultes un pronóstico del tiempo más cerca de la fecha para obtener información precisa.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6857-c3a8-7540-b8c6-bfe8b3afc8a2-0', usage_metadata={'input_tokens': 2075, 'output_tokens': 610, 'total_tokens': 2685, 'input_token_details': {'cache_read': 0}, 'output_to ...
# llm: [AIMessage(content=[{'type': 'text', 'text': 'Basándonos en los datos históricos para el mes de diciembre, **Lima es generalmente más caliente que Medellín.**\n\nAquí está la comparación:\n\n*   **Lima, Perú:** Tiene temperaturas máximas que oscilan entre **22°C y 25°C**.\n*   **Medellín, Colombia:** Tiene temperaturas máximas que promedian entre **22°C y 23.7°C**.\n\nAunque las temperaturas son muy similares, el rango de temperatura máxima en Lima es ligeramente más alto.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-pro', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b685a-992e-7272-96cb-3ee7559f42d7-0', usage_metadata={'input_tokens': 3700, 'output_tokens': 698, 'total_tokens': 4398, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 590}})]
